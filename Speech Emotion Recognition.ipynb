ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_half_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_wag_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_met_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_deep_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cab_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_whip_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shout_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_nag_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_cheek_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_such_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_jug_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ton_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_thin_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shack_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_door_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_phone_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shall_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sheep_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mill_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_food_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_tough_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_reach_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_date_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mop_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_loaf_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_judge_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chalk_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_youth_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_perch_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_jar_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_should_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keen_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_lean_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_soup_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dip_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_talk_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_neat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bean_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_good_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bar_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_fat_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_dab_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mob_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pearl_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_room_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_yes_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hate_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_rain_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_check_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_numb_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_fit_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_chair_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hole_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_moon_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_nice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ring_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_read_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keg_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sell_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_puff_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bone_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_void_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hit_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_goose_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_came_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_limb_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pass_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_kite_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_voice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mood_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mess_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gap_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_laud_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_choice_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_witch_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shawl_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_time_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_road_ps.wav
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_boat_ps.wav
# /kaggle/input/speech-emotion-recognition-crema-and-tess/features.csv

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import np_utils, to_categorical
from keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # accessing the dataset

# %%
tess_path = "/kaggle/input/speech-emotion-recognition-en/Tess"

paths = []
labels = []

for dirname, _, filenames in os.walk(tess_path):
    for filename in filenames:
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
df = pd.DataFrame({'path':paths, 'label':labels})

# %%
df.head()
# Out:
#                                                 path label
# 0  /kaggle/input/speech-emotion-recognition-en/Te...  fear
# 1  /kaggle/input/speech-emotion-recognition-en/Te...  fear
# 2  /kaggle/input/speech-emotion-recognition-en/Te...  fear
# 3  /kaggle/input/speech-emotion-recognition-en/Te...  fear
# 4  /kaggle/input/speech-emotion-recognition-en/Te...  fear

# %%
df.shape
# Out:
# (2800, 2)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.title('Count of Emotions', size=16)
sns.countplot(data=df, x='label')
plt.ylabel('Count', size=12)
plt.xlabel('Emotions', size=12)
sns.despine(top=True, right=True, left=False, bottom=False)
plt.show()

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

# %%
emotion='fear'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='angry'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='happy'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='sad'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='disgust'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion='neutral'
path = np.array(df.path[df.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Data Augmentation

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    n_steps = 12 * pitch_factor  # Assuming 12 steps per octave
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=n_steps)

path = np.array(df['path'])[1]
data, sample_rate = librosa.load(path)

# %%
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=data, sr=sample_rate)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = noise(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = stretch(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = shift(data)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = pitch(data, sample_rate)
plt.figure(figsize=(14,4))
librosa.display.waveshow(y=x, sr=sample_rate)
Audio(x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_features(data):
    result = np.array([])
    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
X, Y = [], []
for path, emotion in zip(df['path'], df['label']):
    print(path, emotion)
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)
# Out:
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_home_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_youth_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_near_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_search_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_pick_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_dodge_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_void_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_sheep_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_pain_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_fall_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_rag_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_when_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_date_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_such_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_burn_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_rose_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_choice_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_ring_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_shall_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_boat_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_wire_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_death_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_love_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_came_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_ripe_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_pike_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_chat_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_keg_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_doll_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_vote_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_cheek_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_limb_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_turn_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_bite_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_mop_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_yes_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_thin_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_shack_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_time_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_good_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_room_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_moon_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_name_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_wash_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_sour_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_goose_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_witch_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_chalk_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_hire_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_base_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_shout_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_seize_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_sell_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_third_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_voice_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_door_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_young_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_pole_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_bone_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_mess_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_soap_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_tool_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_soup_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_rat_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_dog_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_luck_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_dab_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_wag_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_pass_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_sub_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_rot_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_jar_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_chair_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_chief_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_fat_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_rain_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_hole_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_far_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_neat_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_read_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_hash_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_met_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_calm_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_fail_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_gin_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_thumb_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_long_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_cab_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_ton_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_gas_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF_lean_fear.wav fear
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_fear/YAF
ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hole_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_moon_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_nice_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_ring_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_read_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_keg_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_sell_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_puff_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_bone_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_void_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_hit_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_goose_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_came_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_limb_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_pass_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_kite_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_voice_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mood_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_mess_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_gap_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_laud_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_choice_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_witch_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_shawl_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_time_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_road_ps.wav ps
# /kaggle/input/speech-emotion-recognition-en/Tess/YAF_pleasant_surprised/YAF_boat_ps.wav ps

# %%
len(X), len(Y), df.path.shape
# Out:
# (8400, 8400, (2800,))

# %%
Features = pd.DataFrame(X)
Features['labels'] = Y
# Features.to_csv('features_tess.csv', index=False)
Features.head()
# Out:
#             0          1         2          3          4          5  \
# 0 -289.884491  78.489967 -4.182043  23.008759 -16.212927   9.779065
# 1 -217.518811  47.909066  1.136144  11.393647  -4.835249   2.258303
# 2 -337.352753  57.568020  2.710690   9.173580   3.231206  21.607025
# 3 -354.465851  34.171494 -4.104849  15.732566   6.037579  -2.317046
# 4 -263.672696  22.724169 -1.434756   5.927887   4.505200  -4.351952
#
#            6         7          8          9  ...         11         12  \
# 0  10.071579 -6.281810  -0.073306  11.285912  ... -12.476832   6.637176
# 1   7.194518 -4.469236   0.638028   4.877221  ...  -7.614948   5.276382
# 2 -15.860891  4.109444 -17.735071  -0.987638  ...  15.570152  37.689903
# 3  -4.334205 -7.286574 -20.251274   1.631114  ...   0.658645  -1.073156
# 4  -3.891707 -7.453009 -10.475474  -4.778710  ...  -3.332098  -3.472722
#
#           13         14         15         16         17         18  \
# 0  -3.833390 -11.113689   5.443010 -11.874760  19.002893  25.667105
# 1  -5.346372  -8.236519  -2.174869  -4.733379  13.671114  21.910843
# 2  28.943445  -7.832483 -14.114685 -24.493544  12.967581  -6.885558
# 3   2.226918   1.158916   3.610610  -0.503247  22.583223   8.681035
# 4  -2.166129   0.155453   0.291719   1.420505   9.217860   8.626130
#
#           19  labels
# 0  24.925390    fear
# 1  19.853662    fear
# 2   2.306462    fear
# 3  23.693384    fear
# 4  13.842623    fear
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Preparation

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((6300, 20), (6300, 7), (2100, 20), (2100, 7))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((6300, 20), (6300, 7), (2100, 20), (2100, 7))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((6300, 20, 1), (6300, 7), (2100, 20, 1), (2100, 7))

# %% [markdown]
# ## Modeling

# %%
model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=7, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 256)           1536
#
#  max_pooling1d (MaxPooling1D  (None, 10, 256)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           327936
#
#  max_pooling1d_1 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  dropout (Dropout)           (None, 5, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 5, 128)            163968
#
#  max_pooling1d_2 (MaxPooling  (None, 3, 128)           0
#  1D)
#
#  dropout_1 (Dropout)         (None, 3, 128)            0
#
#  conv1d_3 (Conv1D)           (None, 3, 64)             41024
#
#  max_pooling1d_3 (MaxPooling  (None, 2, 64)            0
#  1D)
#
#  dropout_2 (Dropout)         (None, 2, 64)             0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 32)                4128
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 538,823
# Trainable params: 538,823
# Non-trainable params: 0
# _________________________________________________________________

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 99/99 [==============================] - 10s 10ms/step - loss: 1.6557 - accuracy: 0.3071 - val_loss: 1.2488 - val_accuracy: 0.5024 - lr: 0.0010
# Epoch 2/50
# 99/99 [==============================] - 1s 6ms/step - loss: 1.1370 - accuracy: 0.5508 - val_loss: 0.7964 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 3/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.8239 - accuracy: 0.6962 - val_loss: 0.5263 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 4/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.6229 - accuracy: 0.7857 - val_loss: 0.3805 - val_accuracy: 0.8671 - lr: 0.0010
# Epoch 5/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.4749 - accuracy: 0.8379 - val_loss: 0.3070 - val_accuracy: 0.8986 - lr: 0.0010
# Epoch 6/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.3908 - accuracy: 0.8716 - val_loss: 0.2900 - val_accuracy: 0.9038 - lr: 0.0010
# Epoch 7/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.3348 - accuracy: 0.8924 - val_loss: 0.2703 - val_accuracy: 0.9110 - lr: 0.0010
# Epoch 8/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.3075 - accuracy: 0.8975 - val_loss: 0.2493 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 9/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.2693 - accuracy: 0.9173 - val_loss: 0.2612 - val_accuracy: 0.9095 - lr: 0.0010
# Epoch 10/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.2502 - accuracy: 0.9237 - val_loss: 0.2253 - val_accuracy: 0.9276 - lr: 0.0010
# Epoch 11/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.2246 - accuracy: 0.9278 - val_loss: 0.2285 - val_accuracy: 0.9233 - lr: 0.0010
# Epoch 12/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.2264 - accuracy: 0.9284 - val_loss: 0.2214 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 13/50
# 99/99 [==============================] - 1s 9ms/step - loss: 0.2064 - accuracy: 0.9321 - val_loss: 0.1935 - val_accuracy: 0.9381 - lr: 0.0010
# Epoch 14/50
# 99/99 [==============================] - 1s 9ms/step - loss: 0.1927 - accuracy: 0.9419 - val_loss: 0.1939 - val_accuracy: 0.9395 - lr: 0.0010
# Epoch 15/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.1716 - accuracy: 0.9452 - val_loss: 0.2207 - val_accuracy: 0.9305 - lr: 0.0010
# Epoch 16/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.1825 - accuracy: 0.9402 - val_loss: 0.2521 - val_accuracy: 0.9262 - lr: 0.0010
# Epoch 17/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.1778 - accuracy: 0.9444 - val_loss: 0.1823 - val_accuracy: 0.9438 - lr: 0.0010
# Epoch 18/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.1073 - accuracy: 0.9659 - val_loss: 0.1523 - val_accuracy: 0.9543 - lr: 4.0000e-04
# Epoch 19/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.1016 - accuracy: 0.9692 - val_loss: 0.1725 - val_accuracy: 0.9495 - lr: 4.0000e-04
# Epoch 20/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0881 - accuracy: 0.9713 - val_loss: 0.1401 - val_accuracy: 0.9571 - lr: 4.0000e-04
# Epoch 21/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0772 - accuracy: 0.9740 - val_loss: 0.1402 - val_accuracy: 0.9571 - lr: 4.0000e-04
# Epoch 22/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0856 - accuracy: 0.9705 - val_loss: 0.1478 - val_accuracy: 0.9543 - lr: 4.0000e-04
# Epoch 23/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0730 - accuracy: 0.9775 - val_loss: 0.1567 - val_accuracy: 0.9571 - lr: 4.0000e-04
# Epoch 24/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0754 - accuracy: 0.9770 - val_loss: 0.1675 - val_accuracy: 0.9538 - lr: 4.0000e-04
# Epoch 25/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0716 - accuracy: 0.9784 - val_loss: 0.1490 - val_accuracy: 0.9538 - lr: 4.0000e-04
# Epoch 26/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0756 - accuracy: 0.9756 - val_loss: 0.1582 - val_accuracy: 0.9557 - lr: 4.0000e-04
# Epoch 27/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0699 - accuracy: 0.9776 - val_loss: 0.1511 - val_accuracy: 0.9581 - lr: 4.0000e-04
# Epoch 28/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0743 - accuracy: 0.9767 - val_loss: 0.1418 - val_accuracy: 0.9610 - lr: 4.0000e-04
# Epoch 29/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0695 - accuracy: 0.9781 - val_loss: 0.1490 - val_accuracy: 0.9571 - lr: 4.0000e-04
# Epoch 30/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0710 - accuracy: 0.9775 - val_loss: 0.1430 - val_accuracy: 0.9590 - lr: 4.0000e-04
# Epoch 31/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0520 - accuracy: 0.9840 - val_loss: 0.1707 - val_accuracy: 0.9590 - lr: 4.0000e-04
# Epoch 32/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0571 - accuracy: 0.9806 - val_loss: 0.1433 - val_accuracy: 0.9605 - lr: 4.0000e-04
# Epoch 33/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0563 - accuracy: 0.9811 - val_loss: 0.1387 - val_accuracy: 0.9619 - lr: 4.0000e-04
# Epoch 34/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0461 - accuracy: 0.9838 - val_loss: 0.1379 - val_accuracy: 0.9648 - lr: 1.6000e-04
# Epoch 35/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 0.1319 - val_accuracy: 0.9643 - lr: 1.6000e-04
# Epoch 36/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0377 - accuracy: 0.9887 - val_loss: 0.1359 - val_accuracy: 0.9643 - lr: 1.6000e-04
# Epoch 37/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.1303 - val_accuracy: 0.9667 - lr: 1.6000e-04
# Epoch 38/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0332 - accuracy: 0.9892 - val_loss: 0.1333 - val_accuracy: 0.9657 - lr: 1.6000e-04
# Epoch 39/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0379 - accuracy: 0.9873 - val_loss: 0.1489 - val_accuracy: 0.9671 - lr: 1.6000e-04
# Epoch 40/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0333 - accuracy: 0.9895 - val_loss: 0.1583 - val_accuracy: 0.9590 - lr: 1.6000e-04
# Epoch 41/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 0.1355 - val_accuracy: 0.9633 - lr: 6.4000e-05
# Epoch 42/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0256 - accuracy: 0.9924 - val_loss: 0.1348 - val_accuracy: 0.9648 - lr: 6.4000e-05
# Epoch 43/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.1335 - val_accuracy: 0.9652 - lr: 6.4000e-05
# Epoch 44/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0289 - accuracy: 0.9908 - val_loss: 0.1345 - val_accuracy: 0.9676 - lr: 6.4000e-05
# Epoch 45/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.1338 - val_accuracy: 0.9676 - lr: 6.4000e-05
# Epoch 46/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.1331 - val_accuracy: 0.9676 - lr: 2.5600e-05
# Epoch 47/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.1334 - val_accuracy: 0.9681 - lr: 2.5600e-05
# Epoch 48/50
# 99/99 [==============================] - 1s 6ms/step - loss: 0.0223 - accuracy: 0.9930 - val_loss: 0.1331 - val_accuracy: 0.9667 - lr: 2.5600e-05
# Epoch 49/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.1321 - val_accuracy: 0.9681 - lr: 2.5600e-05
# Epoch 50/50
# 99/99 [==============================] - 1s 7ms/step - loss: 0.0200 - accuracy: 0.9941 - val_loss: 0.1334 - val_accuracy: 0.9671 - lr: 1.0240e-05

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 66/66 [==============================] - 0s 4ms/step - loss: 0.1334 - accuracy: 0.9671
# Accuracy of our model on test data :  96.71428799629211 %

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 66/66 [==============================] - 0s 2ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          neutral       neutral
# 1            angry         angry
# 2          neutral       neutral
# 3          disgust       disgust
# 4            angry         angry
# 5          disgust            ps
# 6               ps            ps
# 7              sad           sad
# 8          neutral       neutral
# 9               ps            ps

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.98      0.99      0.98       282
#      disgust       0.96      0.95      0.95       302
#         fear       1.00      0.99      0.99       295
#        happy       0.95      0.94      0.94       313
#      neutral       0.98      0.99      0.99       314
#           ps       0.92      0.93      0.92       293
#          sad       0.99      0.99      0.99       301
#
#     accuracy                           0.97      2100
#    macro avg       0.97      0.97      0.97      2100
# weighted avg       0.97      0.97      0.97      2100
